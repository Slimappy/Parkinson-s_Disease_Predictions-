# %%
# 1Importing necessary libraries
import numpy as np
import pandas as pd
import requests
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, ConfusionMatrixDisplay

# %%
pip install numpy pandas requests joblib seaborn matplotlib scikit-learn imbalanced-learn
# Out:
# Requirement already satisfied: numpy in e:\parkinsons\.venv\lib\site-packages (2.2.4)
# Requirement already satisfied: pandas in e:\parkinsons\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: requests in e:\parkinsons\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: joblib in e:\parkinsons\.venv\lib\site-packages (1.4.2)
# Requirement already satisfied: seaborn in e:\parkinsons\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in e:\parkinsons\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: scikit-learn in e:\parkinsons\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: imbalanced-learn in e:\parkinsons\.venv\lib\site-packages (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\parkinsons\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\parkinsons\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\parkinsons\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\parkinsons\.venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\parkinsons\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\parkinsons\.venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\parkinsons\.venv\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: contourpy>=1.0.1 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\parkinsons\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in e:\parkinsons\.venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\parkinsons\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in e:\parkinsons\.venv\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: six>=1.5 in e:\parkinsons\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 2  URL for data file
url_string = 'https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data'

# %%
# 3 Downloading content from URL and storing it in a local file
url_content = requests.get(url_string).content
with open('data.csv', 'wb') as data_file:
    data_file.write(url_content)

print("Data downloaded and saved as 'data.csv'")
# Out:
# Data downloaded and saved as 'data.csv'

# %%
# 4 Reading Data Into Pandas DataFrame
df = pd.read_csv('data.csv')

# %%
# 5 Exploring Dataset Content
print("Dataset Head:")
print(df.head())
print("\nDataset Tail:")
print(df.tail())
print('Number of Features In Dataset:', df.shape[1])
print('Number of Instances In Dataset:', df.shape[0])
# Out:
# Dataset Head:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]
#
# Dataset Tail:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 190      0.07008  0.02764  19.517       0  0.448439  0.657899 -6.538586
# 191      0.04812  0.01810  19.147       0  0.431674  0.683244 -6.195325
# 192      0.03804  0.10715  17.883       0  0.407567  0.655683 -6.787197
# 193      0.03794  0.07223  19.020       0  0.451221  0.643956 -6.744577
# 194      0.03078  0.04398  21.209       0  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [5 rows x 24 columns]
# Number of Features In Dataset: 24
# Number of Instances In Dataset: 195

# %%
# 6 Dropping the Name Column
df.drop(['name'], axis=1, inplace=True)

# %%
# 7
print('Number of Features In Dataset:', df.shape[1])
print('Number of Instances In Dataset:', df.shape[0])
# Out:
# Number of Features In Dataset: 23
# Number of Instances In Dataset: 195

# %%
# 8 Exploring Information About DataFrame
df.info()
print("\nData Description:")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
#  16  status            195 non-null    int64
#  17  RPDE              195 non-null    float64
#  18  DFA               195 non-null    float64
#  19  spread1           195 non-null    float64
#  20  spread2           195 non-null    float64
#  21  D2                195 non-null    float64
#  22  PPE               195 non-null    float64
# dtypes: float64(22), int64(1)
# memory usage: 35.2 KB
#
# Data Description:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
# 9 Converting status to unsigned integer
df['status'] = df['status'].astype('uint8')

# %%
# 10 Checking For Duplicate Rows In Dataset
print('Number of Duplicated Rows:', df.duplicated().sum())
# Out:
# Number of Duplicated Rows: 0

# %%
# 11 Checking For Missing Values In Dataset
print("Missing Values in Dataset:")
print(df.isna().sum())
# Out:
# Missing Values in Dataset:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# 12 Visualizing the balance of data
sns.countplot(x='status', data=df)
plt.title('Balance of Data')
plt.show()

# %%
# 12 Plotting the correlation heatmap
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, ax=ax)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Box Plot for features
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten()
for i in range(1, len(df.columns)-1):
    sns.boxplot(x='status', y=df.iloc[:, i], data=df, orient='v', ax=axes[i])
plt.tight_layout()
plt.show()

# %%
# Pair plots for selected features
plt.rcParams['figure.figsize'] = (15, 4)
sns.pairplot(df, hue='status', vars=['MDVP:Jitter(%)', 'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP'])
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 4)
sns.pairplot(df, hue='status', vars=['MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA'])
plt.show()

# %%
# Exploring Imbalance in Dataset
print("Status Value Counts:")
print(df['status'].value_counts())
# Out:
# Status Value Counts:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# Extracting Features and Target
X = df.drop(['status'], axis=1)
y = df['status']
print('Feature (X) Shape Before Balancing:', X.shape)
print('Target (y) Shape Before Balancing:', y.shape)
# Out:
# Feature (X) Shape Before Balancing: (195, 22)
# Target (y) Shape Before Balancing: (195,)

# %%
# Initializing SMOTE Object
sm = SMOTE(random_state=300)
# Resampling Data
X, y = sm.fit_resample(X, y)
print('Feature (X) Shape After Balancing:', X.shape)
print('Target (y) Shape After Balancing:', y.shape)
# Out:
# Feature (X) Shape After Balancing: (294, 22)
# Target (y) Shape After Balancing: (294,)

# %%
# Scaling features between -1 and 1 for normalization
scaler = MinMaxScaler((-1, 1))
X_features = scaler.fit_transform(X)
Y_labels = y

# %%
# Splitting the dataset into training and testing sets (80-20)
X_train, X_test, y_train, y_test = train_test_split(X
#  0.86808511 0.84680851 0.79574468 0.81702128 0.77446809 0.8212766
#         nan        nan        nan        nan        nan        nan
#  0.83829787 0.84680851 0.83829787 0.87659574 0.80425532 0.88085106
#  0.83829787 0.84680851 0.83829787 0.87659574 0.80425532 0.88085106
#         nan        nan        nan        nan        nan        nan
#  0.85106383 0.85957447 0.86808511 0.90638298 0.83829787 0.8893617
#  0.85106383 0.85957447 0.86808511 0.90638298 0.83829787 0.8893617
#         nan        nan        nan        nan        nan        nan
#  0.86382979 0.88085106 0.85957447 0.88085106 0.84255319 0.87659574
#  0.86382979 0.88085106 0.85957447 0.88085106 0.84255319 0.87659574
#         nan        nan        nan        nan        nan        nan
#  0.87234043 0.88085106 0.88510638 0.88510638 0.83829787 0.88085106
#  0.87234043 0.88085106 0.88510638 0.88510638 0.83829787 0.88085106
#         nan        nan        nan        nan        nan        nan
#  0.87234043 0.85957447 0.89787234 0.90212766 0.84255319 0.88510638
#  0.87234043 0.85957447 0.89787234 0.90212766 0.84255319 0.88510638]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'random_state': range(30, 210, 30)})

# %%
# Best parameters from GridSearchCV
print("Best Parameters:", CV_dt.best_params_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'random_state': 120}

# %%
# Printing the classification report
print(classification_report(y_test, predDT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        33
#            1       0.86      0.96      0.91        26
#
#     accuracy                           0.92        59
#    macro avg       0.91      0.92      0.91        59
# weighted avg       0.92      0.92      0.92        59

# %%
# Initialize Decision Tree Classifier with valid parameters
dt1 = DecisionTreeClassifier(random_state=120, max_features='sqrt', max_depth=6, criterion='entropy')

# %%
# Fit the model
dt1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, max_features='sqrt',
#                        random_state=120)

# %%
# Make predictions
predDT = dt1.predict(X_test)

# %%
# Print the classification report
print(classification_report(y_test, predDT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        33
#            1       0.96      0.88      0.92        26
#
#     accuracy                           0.93        59
#    macro avg       0.94      0.93      0.93        59
# weighted avg       0.93      0.93      0.93        59

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, predDT)

# Plotting the confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Parkinsons', 'Parkinsons'], yticklabels=['No Parkinsons', 'Parkinsons'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %%
# Getting predicted probabilities
y_pred_proba = dt1.predict_proba(X_test)[:, 1]

# Calculating false positive rate and true positive rate
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

# Plotting the ROC curve
plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, label="AUC = {:.2f}".format(auc))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Dumping Decision Tree Classifier
joblib.dump(dt1, 'dt_clf.pkl')
# Out:
# ['dt_clf.pkl']

# %%
from sklearn.preprocessing import StandardScaler
import joblib

# Assume `scaler` is your fitted StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)  # X_train is your training data

# Save the fitted scaler to a file
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
#0=NO 0
#1=YES 1

import numpy as np
import joblib

# Load the trained model and scaler
model = joblib.load('dt_clf.pkl')  # Load your trained model
scaler = joblib.load('scaler.pkl')  # Load your fitted scaler

# Input data for prediction
input_values = (197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,
                0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,
                -7.348300,0.177551,1.743867,0.085569)

# Convert input data to a numpy array
input_array = np.asarray(input_values)

# Reshape the numpy array
reshaped_input = input_array.reshape(1, -1)

# Standardize the data
standardized_data = scaler.transform(reshaped_input)

# Make the prediction
output_prediction = model.predict(standardized_data)

# Display the prediction result
if output_prediction[0] == 0:
    print("The Person does not have Parkinson's Disease")
else:
    print("The Person has Parkinson's Disease")
# Out:
# The Person does not have Parkinson's Disease

# %%
#197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569
#162.56800,198.34600,77.63000,0.00502,0.00003,0.00280,0.00253,0.00841,0.01791,0.16800,0.00793,0.01057,0.01799,0.02380,0.01170,25.67800,1,0.427785,0.723797,-6.635729,0.209866,1.957961,0.135242
